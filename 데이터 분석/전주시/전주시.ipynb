# %%
import numpy as np
import pandas as pd
import json
import requests
import folium
from folium.plugins import MousePosition

# %%
전주시위경도 = [35.82826330811635, 127.11580526829374]
m = folium.Map(location = 전주시위경도 , zoom_start = 12)

# %%
#cycle
df_c = pd.read_csv('./data/자전거_219.csv')
#protect
df_p = pd.read_csv('./data/전라북도 어린이보호구역.csv')
#school
df_s = pd.read_csv('./data/초중고geocode.csv')
#사고
df_a = pd.read_csv('./data/전주시_자전거사고_추출데이터.csv')
#문화재
df_h = pd.read_csv('./data/전라북도 전주시_문화재현황.csv')

# %%
#난전들로
lo_1 = [[35.79246,127.11679],
        [35.77808,127.11693],
        [35.77771,127.12878]]



#권삼득로
lo_2 = [[35.85147,127.11437],
        [35.8479,127.12052],
        [35.84712,127.12098],
        [35.84677,127.12253],
        [35.84533,127.12557],
        [35.84096,127.13154],
        [35.82316,127.15116]]


#어은로
lo_7 = [[35.8165,127.12301],
         [35.81648,127.12494],
         [35.81553,127.1326],
         [35.81507,127.13298],
         [35.81464,127.13444]]

lo_8  = [[35.81792,127.12291],
         [35.81794,127.12488],
         [35.81656,127.12489]]

#새터로
lo_10 = [[35.83755,127.11215],
          [35.83011,127.11219],
]


#온고을로
lo_9 = [[35.87285,127.06179],
        [35.8587,127.06312],
        [35.84662,127.08865],
        [35.83388,127.10941],
        [35.83364,127.12203]]
#현무2길~ 경기전길
lo_3 = [[35.82011,127.14983],
        [35.81173,127.15158],
        [35.81091,127.15151]]


#기린대로
lo_4 =  [[35.85942,127.09331],
          [35.84579,127.12088],
         [35.83954,127.12942],
         [35.8349,127.13578],
          [35.81995,127.15357],
          [35.81831,127.15455],
          [35.81497,127.15472],
          [35.81201,127.16013],]


#백제대로
lo_5 = [[35.84913,127.16033],
        [35.83973,127.12946],
        [35.83541,127.12362],
        [35.83378,127.12292],
        [35.806,127.12317],
        [35.80365,127.12391],
        [35.79546,127.13258]]

#조경단로
lo_11 = [[35.85123,127.12181],
         [35.85274,127.12721],
         [35.85053,127.13519],
         [35.84265,127.13911],
         [35.83702,127.13744],
         [35.83498,127.13588],
]


#팔달로
lo_6 = [[35.83319,127.13705],
        [35.83045,127.13923],
        [35.82692,127.14349],
        [35.8111,127.14961],
        [35.80537,127.14957],
        [35.80271,127.14801]]

# %%
df_c = df_c[~df_c['노선명'].isin(['바람쐬는길R1' , '전주천2R' , '조경단로1R' ,
                               '기린대로1L' , '기린대로1R' ,'전주천2L','삼천2L' ,
                               '삼천2R' , '백제대로R' , '팔달로R','팔달로L' , 
                               '온고을로2R' , '온고을로2L','백제대로L' ,'조경단로1L' , '조경단로1R', '조경단로2R'])]

# %%
# 자전거 도로
for i in range(df_c['중기점 위도'].count()):
    try:
        folium.PolyLine(
                locations  =[[df_c['기점 위도'][i] , df_c['기점 경도'][i]],
        [df_c['중기점 위도'][i] , df_c['중기점 경도'][i]],
        [df_c['종점 위도'][i] , df_c['종점 경도'][i]] ],

                            tooltip = df_c.index[i]
            ).add_to(m)

    except KeyError:
        print('error')
        pass
    
#히트맵
from folium.plugins import HeatMap
lat = []
long = []
for i  in range(df_a['위도'].count()):
    latitu = df_a['위도'][i] 
    longtitu = df_a['경도'][i] 
    num = df_a['발생건수'][i]
    for j in range(num):
                 lat.append(latitu)
                 long.append(longtitu)

HeatMap(zip(lat,long),
                 
                 
              ).add_to(m)




#문화재
from folium.plugins import MarkerCluster

marker_cluster = MarkerCluster().add_to(m)
for i in range(df_h['posx'].count()):
    folium.Marker(
        [df_h['posy'][i] , df_h['posx'][i]],
        popup = df_h['dataTitle'][i], 
        icon = folium.Icon(color = 'red' , icon = 'bookmark', prefix = 'glyphicon-asterisk'      )
    ).add_to(marker_cluster)
    
#어리이 보호구역
for i in range(df_p['posx'].count()):
    folium.Marker(
        [df_p['posy'][i] , df_p['posx'][i]],
        popup = df_p['pacNm'][i], 
        icon = folium.Icon(color = 'blue' , icon = 'bookmark', prefix = 'glyphicon-asterisk'      )
    ).add_to(marker_cluster)   
#학교
for i in range(df_s['Latitude'].count()):
    folium.Marker(
        [df_s['Latitude'][i] , df_s['Longitude'][i]],
        popup = df_s['학교명'][i], 
        icon = folium.Icon(color = 'green' , icon = 'bookmark', prefix = 'glyphicon-asterisk'      )
    ).add_to(marker_cluster)

#추가도로
folium.PolyLine(
                lo_1,

            tooltip = '난전들로'
            ,color = 'red'
            ).add_to(m)

folium.PolyLine(
                lo_2,

            tooltip = '권삼득로'
            ,color = 'red'
            ).add_to(m)

            
folium.PolyLine(
                lo_7,

            tooltip = '어은로'
            ,color = 'red'
            ).add_to(m)

folium.PolyLine(
                lo_8,

            tooltip = '어은로'
            ,color = 'red'
            ).add_to(m)

folium.PolyLine(
                lo_10,

            tooltip = '새터로'
            ,color = 'red'
            ).add_to(m)

folium.PolyLine(
                lo_3,

            tooltip = '현무2길'
            ,color = 'red'
            ).add_to(m)

            
folium.PolyLine(
                lo_4,

            tooltip = '기린대로'
           
            ).add_to(m)

            
folium.PolyLine(
                lo_5,

            tooltip = '백제대로'
           
            ).add_to(m)

folium.PolyLine(
                lo_6,

            tooltip = '팔달로'
           
            ).add_to(m)

folium.PolyLine(
                lo_9,

            tooltip = '온고을로'
           
            ).add_to(m)



folium.PolyLine(
                lo_11,

            tooltip = '조경단로'
           
            ).add_to(m)
MousePosition().add_to(m)

m
# Out:
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# ...
